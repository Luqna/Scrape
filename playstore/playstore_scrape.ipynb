# %%
# !pip install -q google_play_scraper

# %%
# !pip install -q transformers

# %%
# !pip install -q plotly-express

# %%
# !pip install pyyaml

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, reviews_all
import plotly.express as px

# %%
gojek_project = reviews_all('com.gojek.app', sleep_milliseconds=0, lang= 'id', country='US')

# %%
df = pd.json_normalize(gojek_project)

# %%
df
# Out:
#                                   reviewId                     userName  \
# 0     fa0f13fa-e4b7-44d5-84e7-bd4e415c836c              Erikopurnomoaji
# 1     68a91b39-3a49-44f6-8219-d528d0ee4758                purnama rindu
# 2     ce334075-a66f-4d6a-a2a3-8b762efe9dfb                  Uput Sayang
# 3     d1904d9e-136d-47ea-bd5d-966dfe2bcccd                 Marisah Isah
# 4     05cee923-74ca-4248-94b5-224dc91c95a3               Laksmana Rizki
# ...                                    ...                          ...
# 1189  e6067cda-86ff-4c7d-bd97-d03cf63488fa               OPPO A54 Hitam
# 1190  c6a0c8b0-46e5-4c32-9e38-e2d5e713b85a               Wawan Sarpudin
# 1191  0e1ff594-1337-49ba-b3de-81354e10c352  Kakaren Basreng Dapur Daffa
# 1192  8d7d0ccc-dd34-4e42-94a1-3fea7120418c                Herman Hamzah
# 1193  f24ffbce-dd05-4ec9-a969-ac1cae07e567                   tf1 widodo
#
#                                               userImage  \
# ...

# %%
df['score'].mean()
# Out:
# 3.3098827470686767

# %%
df['reviewCreatedVersion'].value_counts()
# Out:
# 4.83.1    648
# 4.84.1    128
# 4.82.1     64
# 4.81.2     41
# 4.81.1     32
# 4.80.4     11
# 4.78.3      6
# 4.79.2      4
# 4.58.1      4
# 4.69.2      3
# 4.53.1      3
# 4.75.1      3
# 4.55.2      2
# 3.56.2      2
# 4.70.1      2
# 4.78.2      2
# 4.77.2      2
# 4.68.1      2
# 4.2.2       2
# 4.72.1      2
# 4.65.2      2
# 4.9.3       1
# 2.34.1      1
# 4.26.1      1
# 3.15.2      1
# 3.16.1      1
# 4.10.3      1
# 4.77.1      1
# 4.45.1      1
# 4.56.1      1
# 4.22.1      1
# 4.54.2      1
# 4.80.3      1
# 4.12.1      1
# 4.76.2      1
# 4.31.1      1
# 4.59.1      1
# 4.14.2      1
# 4.48.1      1
# 3.36.1      1
# 4.11.1      1
# 4.51.1      1
# 4.34.1      1
# 4.62.1      1
# 4.74.1      1
# 3.51.3      1
# 3.46.1      1
# Name: reviewCreatedVersion, dtype: int64

# %%
df.to_csv("gojek_review.csv", index=False)
